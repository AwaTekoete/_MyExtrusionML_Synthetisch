# %%
# =============================================================================
# Zelle 01 – Smoke Test: Umgebung & Kernpakete pruefen
# =============================================================================
# Ziel: Sicherstellen, dass alle benoetigten Pakete korrekt installiert und
# importierbar sind, bevor mit der fachlichen Umsetzung begonnen wird.
# Hinweis: Alle Firmen-/Produktbezuege in diesem Projekt sind fiktiv
# (Extruder GmbH).
# =============================================================================

import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns
import scipy

print(f"Python-Version:      {sys.version.split()[0]}")
print(f"pandas:               {pd.__version__}")
print(f"numpy:                {np.__version__}")
print(f"scikit-learn:         {sklearn.__version__}")
print(f"matplotlib:           {matplotlib.__version__}")
print(f"seaborn:              {sns.__version__}")
print(f"scipy:                {scipy.__version__}")
print("\n✅ Smoke Test erfolgreich – alle Kernpakete importierbar.")
# Out:
# Python-Version:      3.11.15
# pandas:               2.2.3
# numpy:                2.4.6
# scikit-learn:         1.9.0
# matplotlib:           3.11.1
# seaborn:              0.13.2
# scipy:                1.17.1
#
# ✅ Smoke Test erfolgreich – alle Kernpakete importierbar.
